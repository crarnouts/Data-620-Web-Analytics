# %%
import networkx

G=networkx.Graph()

G.add_node("Corey")

G.add_node("Alyssa")

G.add_node("Tammy")

G.add_node("James")

G.add_node("Mike")

G.add_node("Kathy")

## this will tell you how many nodes you have added
G.nodes()

G.add_edge("Corey","Alyssa")

G.add_edge("Corey","James")

G.add_edge("Corey","Kathy")

G.add_edge("Jared","James")

G.add_edge("Jared","Kathy")

G.add_edge("Madison","James")

G.add_edge("Madison","Kathy")

G.add_edge("Morgan","James")

G.add_edge("Morgan","Kathy")


G.add_edge("James","Kathy")

G.add_edge("Alyssa","Tammy")

G.add_edge("Tammy","Mike")

G.add_edge("Alyssa","Mike")


G.add_edge("Hannah","Mike")

G.add_edge("Hannah","Tammy")


G.add_edge("Haleigh","Mike")

G.add_edge("Haleigh","Tammy")


G.add_edge("Emma","Mike")

G.add_edge("Emma","Tammy")

networkx.draw(G,with_labels=1)

# %% [markdown]
# This graph representation above represents My fiance and I and our families.
